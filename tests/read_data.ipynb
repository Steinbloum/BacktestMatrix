# %%
import pandas as pd
path = 'test_trade_hist.csv'
pd.set_option('display.max_rows',250)

# %%
df = pd.read_csv(path, index_col=0)
df
# Out:
#                     Date     price        size       value  side motive  \
# 0    2021-11-09 04:20:00  2.102100         NaN         NaN   NaN   INIT
# 1    2021-11-09 04:40:00  2.078752  240.528925  500.000000   buy   open
# 2    2021-11-09 04:45:00  2.129559  240.528925  512.220487  sell     tp
# 3    2021-11-09 04:46:00  2.132511  237.283175  506.009021  sell   open
# 4    2021-11-09 05:35:00  2.135621  237.283175  506.746910   buy     tp
# ..                   ...       ...         ...         ...   ...    ...
# 607  2021-11-16 00:34:00  2.811910  154.624371  434.789802  sell   open
# 608  2021-11-16 00:50:00  2.789484  154.624371  431.322249   buy     tp
# 609  2021-11-16 00:51:00  2.787011  156.596811  436.436968   buy   open
# 610  2021-11-16 01:48:00  2.742371  156.596811  429.446503  sell     tp
# 611  2021-11-16 02:02:00  2.719365  159.175090  432.855147   buy   open
#
#            pnl      fees      balance  trade_count position side
# ...

# %%
df = df.loc[df['motive'] == "open"]

# %%
idx = df.index.to_list()

# %%
for n in range(len(idx)):
    if n == idx[n-1]+1:
        print('ERROR')
